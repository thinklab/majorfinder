# %%
import pandas as pd
import numpy as np

# %%
clean_data = pd.read_csv("clean_data.csv")
clean_data.iloc[0]
# Out:
# UNITID                                        100654.0
# CIPCODE                                            100
# CIPDESC                          Agriculture, General.
# CREDLEV                                              3
# DEBT_ALL_STGP_ANY_MDN                               PS
# DEBT_ALL_PP_ANY_MDN                                 PS
# DEBT_ALL_PP_ANY_MDN10YRPAY                          PS
# EARN_MDN_HI_1YR                                     PS
# EARN_MDN_HI_2YR                                     PS
# EARN_PELL_WNE_MDN_1YR                               PS
# EARN_NOPELL_WNE_MDN_1YR                             PS
# EARN_MALE_WNE_MDN_1YR                               PS
# EARN_NOMALE_WNE_MDN_1YR                             PS
# EARN_MDN_1YR                                        PS
# EARN_MDN_4YR                                        PS
# BBRR1_FED_COMP_N                                    PS
# BBRR1_FED_COMP_PAIDINFULL                           PS
# EARN_MDN_5YR                                        PS
# CIPCODE_ORIG                                       100
# INSTNM                        Alabama A & M University
# CONTROL                                            1.0
# DISTANCEONLY                                       0.0
# NPT4_PUB                                       14559.0
# NPT4_PRIV                                          NaN
# COSTT4_A                                       23751.0
# RPY_1YR_RT                                0.1734693878
# RPY_3YR_RT                                0.2531554273
# RPY_5YR_RT                                0.3311258278
# DEBT_MDN                                         16600
# MD_EARN_WNE_P10                                40628.0
# MD_EARN_WNE_P6                                 27851.0
# MD_EARN_WNE_5YR                                52246.0
# Name: 0, dtype: object

# %%
clean_data.replace(["PS", "PrivacySuppressed", "NULL", "NaN"], np.nan)
# Out:
#           UNITID  CIPCODE                                            CIPDESC  \
# 0       100654.0      100                              Agriculture, General.
# 1       100654.0      101              Agricultural Business and Management.
# 2       100654.0      109                                   Animal Sciences.
# 3       100654.0      110                       Food Science and Technology.
# 4       100654.0      110                       Food Science and Technology.
# ...          ...      ...                                                ...
# 229183       NaN     5201                        Business/Commerce, General.
# 229184       NaN     5203                   Accounting and Related Services.
# 229185       NaN     5204  Business Operations Support and Assistant Serv...
# 229186       NaN     5204  Business Operations Support and Assistant Serv...
# 229187       NaN     5214                                         Marketing.
#
#         CREDLEV DEBT_ALL_STGP_ANY_MDN DEBT_ALL_PP_ANY_MDN  \
# 0             3                   NaN                 NaN
# 1             3                   NaN                 NaN
# 2             3                   NaN                 NaN
# 3             3                   NaN                 NaN
# 4             5                   NaN                 NaN
# ...         ...                   ...                 ...
# 229183        2                   NaN                 NaN
# 229184        1                   NaN                 NaN
# 229185        1                   NaN                 NaN
# 229186        2                   NaN                 NaN
# 229187        3                   NaN                 NaN
#
#        DEBT_ALL_PP_ANY_MDN10YRPAY EARN_MDN_HI_1YR EARN_MDN_HI_2YR  \
# 0                             NaN             NaN             NaN
# 1                             NaN             NaN             NaN
# 2                             NaN             NaN             NaN
# 3                             NaN             NaN             NaN
# 4                             NaN             NaN             NaN
# ...                           ...             ...             ...
# 229183                        NaN             NaN             NaN
# 229184                        NaN             NaN             NaN
# 229185                        NaN             NaN             NaN
# 229186                        NaN             NaN             NaN
# 229187                        NaN             NaN             NaN
#
#        EARN_PELL_WNE_MDN_1YR  ... NPT4_PUB NPT4_PRIV COSTT4_A    RPY_1YR_RT  \
# 0                        NaN  ...  14559.0       NaN  23751.0  0.1734693878
# 1                        NaN  ...  14559.0       NaN  23751.0  0.1734693878
# 2                        NaN  ...  14559.0       NaN  23751.0  0.1734693878
# 3                        NaN  ...  14559.0       NaN  23751.0  0.1734693878
# 4                        NaN  ...  14559.0       NaN  23751.0  0.1734693878
# ...                      ...  ...      ...       ...      ...           ...
# 229183                   NaN  ...      NaN       NaN      NaN           NaN
# 229184                   NaN  ...      NaN       NaN      NaN           NaN
# 229185                   NaN  ...      NaN       NaN      NaN           NaN
# 229186                   NaN  ...      NaN       NaN      NaN           NaN
# 229187                   NaN  ...      NaN       NaN      NaN           NaN
#
#           RPY_3YR_RT    RPY_5YR_RT DEBT_MDN MD_EARN_WNE_P10  MD_EARN_WNE_P6  \
# 0       0.2531554273  0.3311258278    16600         40628.0         27851.0
# 1       0.2531554273  0.3311258278    16600         40628.0         27851.0
# 2       0.2531554273  0.3311258278    16600         40628.0         27851.0
# 3       0.2531554273  0.3311258278    16600         40628.0         27851.0
# 4       0.2531554273  0.3311258278    16600         40628.0         27851.0
# ...              ...           ...      ...             ...             ...
# 229183           NaN           NaN      NaN             NaN             NaN
# 229184           NaN           NaN      NaN             NaN             NaN
# 229185           NaN           NaN      NaN             NaN             NaN
# 229186           NaN           NaN      NaN             NaN             NaN
# 229187           NaN           NaN      NaN             NaN             NaN
#
#        MD_EARN_WNE_5YR
# 0              52246.0
# 1              52246.0
# 2              52246.0
# 3              52246.0
# 4              52246.0
# ...                ...
# 229183             NaN
# 229184             NaN
# 229185             NaN
# 229186             NaN
# 229187             NaN
#
# [229188 rows x 32 columns]

# %%
for col in clean_data.columns:
    clean_data[col] = pd.to_numeric(clean_data[col], errors="ignore")
# Out:
# /var/folders/91/7bq2ffcs2jq2_x6yfbfl8_2h0000gn/T/ipykernel_21311/1784778837.py:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   clean_data[col] = pd.to_numeric(clean_data[col], errors="ignore")

# %%
clean_data
# Out:
#           UNITID  CIPCODE                                            CIPDESC  \
# 0       100654.0      100                              Agriculture, General.
# 1       100654.0      101              Agricultural Business and Management.
# 2       100654.0      109                                   Animal Sciences.
# 3       100654.0      110                       Food Science and Technology.
# 4       100654.0      110                       Food Science and Technology.
# ...          ...      ...                                                ...
# 229183       NaN     5201                        Business/Commerce, General.
# 229184       NaN     5203                   Accounting and Related Services.
# 229185       NaN     5204  Business Operations Support and Assistant Serv...
# 229186       NaN     5204  Business Operations Support and Assistant Serv...
# 229187       NaN     5214                                         Marketing.
#
#         CREDLEV DEBT_ALL_STGP_ANY_MDN DEBT_ALL_PP_ANY_MDN  \
# 0             3                    PS                  PS
# 1             3                    PS                  PS
# 2             3                    PS                  PS
# 3             3                    PS                  PS
# 4             5                    PS                  PS
# ...         ...                   ...                 ...
# 229183        2                   NaN                 NaN
# 229184        1                   NaN                 NaN
# 229185        1                   NaN                 NaN
# 229186        2                   NaN                 NaN
# 229187        3                   NaN                 NaN
#
#        DEBT_ALL_PP_ANY_MDN10YRPAY EARN_MDN_HI_1YR EARN_MDN_HI_2YR  \
# 0                              PS              PS              PS
# 1                              PS             NaN             NaN
# 2                              PS              PS              PS
# 3                              PS              PS              PS
# 4                              PS              PS              PS
# ...                           ...             ...             ...
# 229183                        NaN             NaN             NaN
# 229184                        NaN             NaN             NaN
# 229185                        NaN             NaN             NaN
# 229186                        NaN             NaN             NaN
# 229187                        NaN             NaN             NaN
#
#        EARN_PELL_WNE_MDN_1YR  ... NPT4_PUB NPT4_PRIV COSTT4_A    RPY_1YR_RT  \
# 0                         PS  ...  14559.0       NaN  23751.0  0.1734693878
# 1                         PS  ...  14559.0       NaN  23751.0  0.1734693878
# 2                         PS  ...  14559.0       NaN  23751.0  0.1734693878
# 3                         PS  ...  14559.0       NaN  23751.0  0.1734693878
# 4                         PS  ...  14559.0       NaN  23751.0  0.1734693878
# ...                      ...  ...      ...       ...      ...           ...
# 229183                    PS  ...      NaN       NaN      NaN           NaN
# 229184                    PS  ...      NaN       NaN      NaN           NaN
# 229185                    PS  ...      NaN       NaN      NaN           NaN
# 229186                    PS  ...      NaN       NaN      NaN           NaN
# 229187                    PS  ...      NaN       NaN      NaN           NaN
#
#           RPY_3YR_RT    RPY_5YR_RT DEBT_MDN MD_EARN_WNE_P10  MD_EARN_WNE_P6  \
# 0       0.2531554273  0.3311258278    16600         40628.0         27851.0
# 1       0.2531554273  0.3311258278    16600         40628.0         27851.0
# 2       0.2531554273  0.3311258278    16600         40628.0         27851.0
# 3       0.2531554273  0.3311258278    16600         40628.0         27851.0
# 4       0.2531554273  0.3311258278    16600         40628.0         27851.0
# ...              ...           ...      ...             ...             ...
# 229183           NaN           NaN      NaN             NaN             NaN
# 229184           NaN           NaN      NaN             NaN             NaN
# 229185           NaN           NaN      NaN             NaN             NaN
# 229186           NaN           NaN      NaN             NaN             NaN
# 229187           NaN           NaN      NaN             NaN             NaN
#
#        MD_EARN_WNE_5YR
# 0              52246.0
# 1              52246.0
# 2              52246.0
# 3              52246.0
# 4              52246.0
# ...                ...
# 229183             NaN
# 229184             NaN
# 229185             NaN
# 229186             NaN
# 229187             NaN
#
# [229188 rows x 32 columns]

# %%
clean_data.isna().mean().sort_values()
# Out:
# CIPCODE                       0.000000
# CIPDESC                       0.000000
# CREDLEV                       0.000000
# EARN_MDN_1YR                  0.000000
# EARN_NOMALE_WNE_MDN_1YR       0.000000
# EARN_MALE_WNE_MDN_1YR         0.000000
# EARN_NOPELL_WNE_MDN_1YR       0.000000
# EARN_PELL_WNE_MDN_1YR         0.000000
# CIPCODE_ORIG                  0.000000
# EARN_MDN_5YR                  0.000000
# DEBT_ALL_STGP_ANY_MDN         0.038636
# EARN_MDN_4YR                  0.038636
# BBRR1_FED_COMP_N              0.038636
# BBRR1_FED_COMP_PAIDINFULL     0.038636
# DEBT_ALL_PP_ANY_MDN           0.038636
# DEBT_ALL_PP_ANY_MDN10YRPAY    0.038636
# UNITID                        0.044108
# DISTANCEONLY                  0.067530
# CONTROL                       0.067530
# INSTNM                        0.067530
# DEBT_MDN                      0.071561
# MD_EARN_WNE_P6                0.086318
# MD_EARN_WNE_P10               0.088281
# MD_EARN_WNE_5YR               0.088848
# EARN_MDN_HI_1YR               0.104896
# RPY_3YR_RT                    0.110874
# RPY_1YR_RT                    0.113571
# RPY_5YR_RT                    0.115032
# EARN_MDN_HI_2YR               0.119435
# COSTT4_A                      0.132503
# NPT4_PUB                      0.431458
# NPT4_PRIV                     0.667727
# dtype: float64
